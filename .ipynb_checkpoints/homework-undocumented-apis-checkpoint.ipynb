# %% [markdown]
# # Homework - Finding APIs
#
# In this homework we're going to reverse-engineer [Airbnb](https://en.wikipedia.org/wiki/Airbnb)'s interactive tool to estimate the potential earnings by hosting.
#
# You can read the [press release](https://news.airbnb.com/interactive-tool-estimates-potential-monthly-host-earnings-on-airbnb/) for the tool, and view the tool on [their website](https://www.airbnb.com/host/homes?room_type=ENTIRE_HOME).

# %% [markdown]
# ## Getting started
#
# As a reminder, you can follow along to the basic steps to do this from the [tutorial we went over during class](https://inspectelement.org/apis.html#tutorial).

# %% [markdown]
# ### 0) Go to the website, and open the developer tools.
#
# As a reminder, the website we'll be inspecting today is here:
# https://www.airbnb.com/host/homes?room_type=ENTIRE_HOME
#
# Visit that link, and open up the developer tools (see step 1 in the tutorial).

# %% [markdown]
# ### 1) Use the site as intended
#
# With the developer tools open, go to the "Network" tab.
#
# Go back to the Airbnb website window, and search a new address. It can be any address. For example, you can check the area surrounding Columbia by entering, "Pulitzer Hall, Broadway, New York, NY, USA".
#
# We're just doing this step to trigger the network request (API call) that requests the potential earnings for the new address.

# %% [markdown]
# ### 2) Find the API call
#
# After searching a new address, you should see more entries in the "Network" tab in the developer tools.
#
# Try to find the exact API call that pulls the estimated earnings.
#
# Hint: this is steps [3 and 4](https://inspectelement.org/apis.html#filter-requests-by-fetchxhr) in the tutorial.
#
# When you feel like you found the API call, copy it as a curl, and convert that curl into a Python request using [curlconverter.com](https://curlconverter.com/).
#
# Paste the request into the cell below, and run it.

# %%
import requests

cookies = {
    'bev': '1689089958_ZTk4MTEyZDAyMjJi',
    'everest_cookie': '1689089958.x5Df2SHVBDIry0OUsXRx.96lIwBpcd4wra-9BPasCKYaMWOfWFWveMZoV3-PzMKA',
    'country': 'US',
    'cdn_exp_0f32753c9def38c21': 'control',
    'cdn_exp_a9d6070a0416b7ace': 'control',
    'cdn_exp_aff0e719002b8324c': 'control',
    'cdn_exp_c170bbabd6f357ac2': 'treatment',
    'cdn_exp_d878adcbec316edd5': 'treatment',
    'cdn_exp_75122dbaede94cfd0': 'control',
    'jitney_client_session_id': '6a3568a0-8e47-48a1-8c75-067ac47759e6',
    'jitney_client_session_created_at': '1689089960.786',
    'OptanonConsent': '0_183215%3A1%2C0_200000%3A1%2C0_183345%3A1%2C0_183243%3A1%2C0_183216%3A1%2C0_179751%3A1%2C0_200003%3A1%2C0_200005%3A1%2C0_179754%3A1%2C0_179750%3A1%2C0_179737%3A1%2C0_179744%3A1%2C0_179739%3A1%2C0_179743%3A1%2C0_179749%3A1%2C0_200012%3A1%2C0_200011%3A1%2C0_183217%3A1%2C0_183219%3A1%2C0_183096%3A1%2C0_179747%3A1%2C0_179740%3A1%2C0_179752%3A1%2C0_183241%3A1%2C0_200007%3A1%2C0_183346%3A1%2C0_183095%3A1%2C0_210000%3A1%2C0_210001%3A1%2C0_210002%3A1',
    'ak_bmsc': 'CAE95B3769B3065B39955C04B1C32672~000000000000000000000000000000~...',
    'tzo': '-240',
    'fbm_138566025676': 'base_domain=.airbnb.com',
    '_airbed_session_id': '7cbc4711540c212acb0f3d9c85923e08',
    'auth_jitney_session_id': '2dfae229-3592-4e81-afd3-dce4253f3839',
    'fbsr_138566025676': 'CBzZv0J2mO4w1Nqnjzli42jFPSm8gqgTfwbf3LL61Rg....',
    '_pt': '1--WyI5MGRhYWY4ZTlhOWRmOTZkZTFkNmVmM2U3MWEzYmQwZTg3ZjQzZTM4Il0%3D--049ed6ae33a2b4331385a20dc2e67a8a1cd0d1dd',
    'hli': '1',
    'rclmd': '%7B%223016829%22%3A%22otp_phone%22%7D',
    'roles': '0',
    'rclu': '%7B%223016829%22%3A%22sEp5n4DWJ3MYqZdfo3ld1R804JzuJn6juwLz6AlyrEQ%3D%22%7D',
    'abb_fa2': '%7B%22user_id%22%3A%2277%7C1%7CysCSEf3mnNo6r8nmTebMSOh9reujvkcdu0v38p4XMAZ2qEgqnyjo%22%7D',
    '_aat': '0%7C9VHE8dk16aaP1Mtsh3mnaNiDuQWWMhnWQqjSECB6efppQZ5HEzKpCGNWWrL%2BtkGx',
    'li': '1',
    'hli': '1',
    '_csrf_token': 'V4%24.airbnb.com%24f773lvRTJsM%24Bw5ZOQG3WSiB6CHoEhVppXi_jEFuIwm3R3fP4N-oeO4%3D',
    'flags': '8448',
    '_user_attributes': '%7B%22curr%22%3A%22USD%22%2C%22guest_exchange%22%3A1%2C%22device_profiling_session_id%22%3A%221689093592-3016829-dbe932e0e8d317c42f94a93f%22%2C%22giftcard_profiling_session_id%22%3A%221689093592-3016829-e7c36699fda48edf6e576614%22%2C%22reservation_profiling_session_id%22%3A%221689093592-3016829-4ccb4bbbca2138606ee9db86%22%2C%22id%22%3A3016829%2C%22hash_user_id%22%3A%2290daaf8e9a9df96de1d6ef3e71a3bd0e87f43e38%22%2C%22eid%22%3A%22dtEXtSHbgJwl2ge4PyuUhg%3D%3D%22%2C%22num_h%22%3A0%2C%22name%22%3A%22Rob%22%2C%22num_action%22%3A0%2C%22is_admin%22%3Afalse%2C%22can_access_photography%22%3Afalse%2C%22travel_credit_status%22%3Anull%2C%22referrals_info%22%3A%7B%22receiver_max_savings%22%3Anull%2C%22receiver_savings_percent%22%3Anull%2C%22receiver_signup%22%3Anull%2C%22referrer_guest%22%3A%22%2420%22%2C%22terms_and_conditions_link%22%3A%22%2Fhelp%2Farticle%2F2269%22%2C%22wechat_link%22%3Anull%2C%22offer_discount_type%22%3Anull%7D%7D',
    'cfrmfctr': 'MOBILE',
    'frmfctr': 'compact',
    'jitney_client_session_updated_at': '1689094056.855',
    'OptanonAlertBoxClosed': '2023-07-11T16%3A47%3A37.742Z',
    'cbkp': '1',
    'previousTab': '%7B%22id%22%3A%227fe74388-92df-42f7-abdc-119e85641ed5%22%2C%22url%22%3A%22https%3A%2F%2Fwww.airbnb.com%2
221689093592-3016829-dbe932e0e8d317c42f94a93f%22%2C%22giftcard_profiling_session_id%22%3A%221689093592-3016829-e7c36699fda48edf6e576614%22%2C%22reservation_profiling_session_id%22%3A%221689093592-3016829-4ccb4bbbca2138606ee9db86%22%2C%22id%22%3A3016829%2C%22hash_user_id%22%3A%2290daaf8e9a9df96de1d6ef3e71a3bd0e87f43e38%22%2C%22eid%22%3A%22dtEXtSHbgJwl2ge4PyuUhg%3D%3D%22%2C%22num_h%22%3A0%2C%22name%22%3A%22Rob%22%2C%22num_action%22%3A0%2C%22is_admin%22%3Afalse%2C%22can_access_photography%22%3Afalse%2C%22travel_credit_status%22%3Anull%2C%22referrals_info%22%3A%7B%22receiver_max_savings%22%3Anull%2C%22receiver_savings_percent%22%3Anull%2C%22receiver_signup%22%3Anull%2C%22referrer_guest%22%3A%22%2420%22%2C%22terms_and_conditions_link%22%3A%22%2Fhelp%2Farticle%2F2269%22%2C%22wechat_link%22%3Anull%2C%22offer_discount_type%22%3Anull%7D%7D; cfrmfctr=MOBILE; frmfctr=compact; jitney_client_session_updated_at=1689094056.855; OptanonAlertBoxClosed=2023-07-11T16%3A47%3A37.742Z; cbkp=1; previousTab=%7B%22id%22%3A%227fe74388-92df-42f7-abdc-119e85641ed5%22%2C%22url%22%3A%22https%3A%2F%2Fwww.airbnb.com%2Fhost%2Fhomes%3Froom_type%3DENTIRE_HOME%22%7D; bm_sv=0C907A0F621833A743EE134FE64C122C~~1',
    'referer': 'https://www.airbnb.com/host/homes?room_type=ENTIRE_HOME',
    'sec-ch-ua': '"Not.A/Brand";v="8", "Chromium";v="114", "Google Chrome";v="114"',
    'sec-ch-ua-mobile': '?1',
    'sec-ch-ua-platform': '"Android"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Mobile Safari/537.36',
    'x-airbnb-api-key': 'd306zoyjsyarp7ifhu67rjxn52tv0t20',
    'x-airbnb-graphql-platform': 'web',
    'x-airbnb-graphql-platform-client': 'minimalist-niobe',
    'x-airbnb-supports-airlock-v2': 'true',
    'x-client-request-id': '1a9oqkm04fuhk70o5ukmb0qj16up',
    'x-client-version': 'ecb629860087a97c10f8eeb38145022fd24013cd',
    'x-csrf-token': 'V4$.airbnb.com$f773lvRTJsM$Bw5ZOQG3WSiB6CHoEhVppXi_jEFuIwm3R3fP4N-oeO4=',
    'x-csrf-without-token': '1',
    'x-niobe-short-circuited': 'true',
}

params = {
    'operationName': 'GetHostEstimateData',
    'locale': 'en',
    'currency': 'USD',
    'variables': '{"durationGranularity":["MONTHLY"],"source":"HOST_LANDING_PAGE","location":{"searchQuery":"2142 West Concord Place, Chicago, IL, USA"},"roomTypeCategory":"ENTIRE_HOME","bedroom":1,"fetchDebugInfo":false}',
    'extensions': '{"persistedQuery":{"version":1,"sha256Hash":"0ce03f62bd7e5cdaa639675604ea67ff782d277728c7c73b150b73c286ff9929"}}',
}

response = requests.get('https://www.airbnb.com/api/v3/GetHostEstimateData', params=params, cookies=cookies, headers=headers)

# %% [markdown]
# store the JSON response (dictionary) in a `records` variable to parse.

# %%
records = response.json()

# %% [markdown]
# here's a trick to see the keys in the dictionary.

# %%
records.keys()
# Out:
# dict_keys(['data', 'extensions'])

# %% [markdown]
# If the dictionary is nested, you can go to the next key, and then list the keys, again.

# %%
records['data']['presentation'].keys()
# Out:
# dict_keys(['__typename', 'hostEstimate'])

# %% [markdown]
# ### 3) Parse the response
# In the cell below, traverse the JSON response and get the estimated revenue per night. Store this in a variable named `estimate`.

# %%
#kept iterating on layers until I got to sections, which is a list
for k, v in records['data']['presentation']['hostEstimate']['hostEstimateScreen']['header'].items():
    print(k, v)
    print('------------------')
# Out:
# __typename HostEstimateHeader
# ------------------
# sections [{'__typename': 'HostEstimateHeaderSection', 'label': {'__typename': 'I18nText', 'localizedString': 'Hosts in your area earn an average of*'}, 'suffix': {'__typename': 'I18nText', 'localizedString': '/ month'}, 'value': '$3,741'}, {'__typename': 'HostEstimateHeaderSection', 'label': {'__typename': 'I18nText', 'localizedString': 'They earn'}, 'suffix': {'__typename': 'I18nText', 'localizedString': '/ night'}, 'value': '$129'}, {'__typename': 'HostEstimateHeaderSection', 'label': {'__typename': 'I18nText', 'localizedString': "They're booked"}, 'suffix': {'__typename': 'I18nText', 'localizedString': 'nights / month'}, 'value': '29'}]
# ------------------
# ...

# %%
estimate = records['data']['presentation']['hostEstimate']['hostEstimateScreen']['header']['sections'][1]['value'] # if it isn't obvious, you should change this line of code
estimate
# Out:
# '$129'

# %% [markdown]
# ### 4) Recycle the API call
#
# Next, we're going to make the API call reusable. In the cells below fill in what the URL is for the API call

# %%
# what is the URL of the API we found?
url = 'https://www.airbnb.com/api/v3/GetHostEstimateData'

# copy the necessary headers here
headers = { 
    'x-airbnb-api-key': 'd306zoyjsyarp7ifhu67rjxn52tv0t20',
}

# copy the necessary parameters here, but replace the hard-coded address with the variable
address = '2142 West Concord Place, Chicago, IL, USA'

params = {
    'operationName': 'GetHostEstimateData',
    'locale': 'en',
    'currency': 'USD',
    'variables': '{"durationGranularity":["MONTHLY"],"source":"HOST_LANDING_PAGE","location":{"searchQuery":"' + address + '"},"roomTypeCategory":"ENTIRE_HOME","bedroom":1,"fetchDebugInfo":false}',
    'extensions': '{"persistedQuery":{"version":1,"sha256Hash":"0ce03f62bd7e5cdaa639675604ea67ff782d277728c7c73b150b73c286ff9929"}}',    
}

response = requests.get(url, params=params, headers=headers)
response.json()
# Out:
# {'data': {'presentation': {'__typename': 'RootPresentationContainer',
#    'hostEstimate': {'__typename': 'HostEstimatePresentationContainer',
#     'hostEstimateScreen': {'__typename': 'HostEstimateScreen',
#      'header': {'__typename': 'HostEstimateHeader',
#       'sections': [{'__typename': 'HostEstimateHeaderSection',
#         'label': {'__typename': 'I18nText',
#          'localizedString': 'Hosts in your area earn an average of*'},
#         'suffix': {'__typename': 'I18nText', 'localizedString': '/ month'},
#         'value': '$3,741'},
#        {'__typename': 'HostEstimateHeaderSection',
#         'label': {'__typename': 'I18nText', 'localizedString': 'They earn'},
#         'suffix': {'__typename': 'I18nText', 'localizedString': '/ night'},
#         'value': '$129'},
#        {'__typename': 'HostEstimateHeaderSection',
#         'label': {'__typename': 'I18nText',
#          'localizedString': "They're booked"},
#         'suffix': {'__typename': 'I18nText',
# ...

# %% [markdown]
# ### 5) Make more API calls
# Run the API call for at least two other `address`es

# %%
import time

# %%
# here are some random addresses you can use:
addresses = [
    "Pulitzer Hall, Broadway, New York, NY, USA",
    '1932 Bryant Avenue, The Bronx, NY, USA',
    '810 39th Avenue Northeast, Naples, FL, USA',
    '86 North 6th Street, Brooklyn, NY, USA'
]

# %%
responses = [] # we'll record the API responses here.
for address in addresses:
    params = {
            'operationName': 'GetHostEstimateData',
    'locale': 'en',
    'currency': 'USD',
    'variables': '{"durationGranularity":["MONTHLY"],"source":"HOST_LANDING_PAGE","location":{"searchQuery":"' + address + '"},"roomTypeCategory":"ENTIRE_HOME","bedroom":1,"fetchDebugInfo":false}',
    'extensions': '{"persistedQuery":{"version":1,"sha256Hash":"0ce03f62bd7e5cdaa639675604ea67ff782d277728c7c73b150b73c286ff9929"}}',    

    }
    response = requests.get(url, params=params, headers=headers)
    
    # check if the API call was successful by checking the status
    if response.status_code == 200:
        responses.append(response.json())
    
    # put some time between requests
    time.sleep(1)

# %% [markdown]
# ### 6) What are the daily estimated earnings?
# Print the estimated earning per night for each address in `responses`.

# %%
for records in responses:
    estimate = records['data']['presentation']['hostEstimate']['hostEstimateScreen']['header']['sections'][1]['value']
    print(estimate)
# Out:
# $209
# $112
# $110
# $207

# %% [markdown]
# ### Extra Credit
# 1. We just printed the estimates above, can you also record the query addresses and print those, too?
# 2. Check different rental configurations in the number of "bedrooms".
# 3. What other information is hidden in the API response, anything interesting?
#
# ### Super Extra
# 1. Get a random sample of addresses from usps.biglocalnews.org
#     - Merge socioeconomic data from the American Community Survey
#     - Format the addresses to match the input in the Airbnb site.
# 2. Check if there are patterns in which areas are given the lowest estimates.
